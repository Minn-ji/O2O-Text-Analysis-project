# %%
# %cd ..
# %cd O2O-Text-Analysis-project

# %%
from IPython.core.display import HTML
import pyLDAvis
from pyLDAvis import gensim_models
from gensim import corpora
import gensim

# %%
word_dict = corpora.Dictionary.load('result/word_dict.dict')
corpus = corpora.MmCorpus('result/corpus.mm')
N_TOPICS = 10
ldamodel = gensim.models.ldamodel.LdaModel.load('result/lda_model')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pyLDAvis.enable_notebook() # 동그라미가 토픽이고 가까우면 유사한 것
vis = pyLDAvis.gensim_models.prepare(ldamodel, corpus, word_dict)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el870391406490378664648844869205" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...
