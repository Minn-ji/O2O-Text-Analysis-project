# %%
import logging

logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# %%
import pandas as pd
from konlpy.tag import Okt
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from matplotlib import rcParams, font_manager
import warnings

rcParams['font.family'] = 'malgun.ttf'
rcParams['axes.unicode_minus'] = False
from draw_wordCloud_sw import generate_wordcloud_sw

# %% [markdown]
# ### 요기요 이상치

# %%
yogiyo_outlier = pd.read_csv('result/yogiyo_2020-02-27~2020-04-26.csv')

# %%
yogiyo_stop = ['하다', '되다', '있다', '없다', '되었', '해주다', '좋다', '편하다', '너무', '쓰다', '자다', '같다', '많다', '먹다', '시키다', '이다', '굳다', '줄다', '보다', '아니다', '되어다','편리하다']

# %%
generate_wordcloud_sw(yogiyo_outlier, 'yogiyo' yogiyo_stop)

# %% [markdown]
# ### SkyScanner 이상치

# %%
skyscanner_outlier = pd.read_csv('result/skyscanner_2015-09-07~2015-12-14.csv')

# %%
skyscanner_stop = ['하다', '되다', '있다', '없다', '되었', '해주다', '좋다', '편하다', '굳다', '자다', '찾다', '같다', '편리하다', '쉬다', '너무',
                   '이다', '보다', '유용하다', '저렴하다', '빠르다', '나오다', '안되다', '않다', '가능하다', '가다', '많다', '싸다', '뜨다', '쓰다',
                   '간편하다', '다양하다', '알다', '되어다', '해보다', '필요없다', '알아보다', '감사하다', '돼다', '써다', '많이', '차다', '잘쓰다']

# %%
generate_wordcloud_sw(skyscanner_outlier, 'skyscanner', skyscanner_stop)

# %% [markdown]
# ### Nol 이상치

# %%
nol_outlier = pd.read_csv("result/nol_2020-04-14~2020-05-12.csv")

# %%
nol_stop = ['하다', '되다', '있다', '없다', '되었', '해주다', '좋다', '놀다', '같다', '깔다', '너무', '안되다', '많다', '편하다', ' 자다', '아니다'
            '이다', '주다', '이다', '자다', '보다', '아니다', '받다', '모르다', '쓰다', '모르다', '편리하다', '가다', '나오다', '않다', '갈다', '오다', '알다', '간편하다'
            '괜찮다', '싸다', '쓰다', '써다', '많이', '간편하다', '괜찮다', '유용하다', '뜨다', '그렇다', '넘다', '그리고', '여기다', '저렴하다', '쓸다', '감사하다', '찾다', '아직', '들다'
            '잇다', '들다', '돼다', '다른', '야하다', '해보다']

# %%
generate_wordcloud_sw(nol_outlier, 'nol', nol_stop)

# %% [markdown]
# ### Uber 이상치

# %%
uber_outlier = pd.read_csv("result/uber_2021-09-28~2022-01-21.csv")

# %%
uber_stop = ['하다', '되다', '있다', '없다', '되었', '해주다', '좋다', '놀다', '않다', '잡히다', '않다', '쓰다', '같다', '보다', '불편하다', '너무', '자다', '가다', '오다', '많이',
             '아니다', '모르다', '아니다', '오다', '받다', '들다', '편하다', '써다', '타다', '만들다', '건지다', '새롭다', '주다', '이다', '잡다', '나오다', '부르다', '뜨다', '기다리다', '돼다'
             '이렇다', '되어다', '돼다', '그리고', '많다', '쓸다', '어떻다', '이렇다', '걸리다', '바뀌다', '넣다', '어렵다', '놓다', '나다', '싶다', '그렇다', '줄다', '이렇게', '깔다']

# %%
generate_wordcloud_sw(uber_outlier, 'uber_taxi', uber_stop)

# %% [markdown]
# ### 카카오택시 이상치

# %%
kakao_outlier = pd.read_csv('result/kakao_2021-12-03~2021-12-31.csv')

# %%
kakao_stop = ['하다', '되다', '있다', '없다', '되었', '해주다', '좋다', '가다', '잡다', '잡히다', '아니다', '같다', '뜨다', '않다', '오다', '자다', '들다',
              '지다', '찾다', '이렇다', '나오다', '받다', '줄다', '타다', '보다', '이다', '너무', '기다리다', '주다', '쓰다', '되어다', '놓다', '부르다', '야하다']

# %%
generate_wordcloud_sw(kakao_outlier, 'kakao_taxi', kakao_stop)

# %% [markdown]
# ### 여기어때 이상치

# %%
ddae_outlier = pd.read_csv('result/ddae_2019-06-11~2019-08-02.csv')

# %%
ddae_stop = ['하다', '되다', '있다', '없다', '되었', '해주다', '좋다', '가다', '잡다', '잡히다', '아니다', '같다', '뜨다', '않다', '오다', '자다', '들다',
              '지다', '찾다', '이렇다', '나오다', '받다', '줄다', '타다', '보다', '이다', '너무', '기다리다', '주다', '쓰다', '되어다', '놓다', '부르다', '야하다',
              '편하다', '많다', '안되다', '편리하다', '여기다', '쉬다', '많이', '싸다', '저렴하다', '간편하다', '유용하다', '넘다', '괜찮다', '해보다', '감사하다',
              '쓸다', '알다', '놀다', '쉽다', '용하다', '빠르다', '가능하다', '잘쓰다', '다른', '써다', '나쁘다', '아직', '굳다', '짜증나다', '다양하다', '들어가다',
              '차다', '모르다', '필요하다', '드리다', '조아', '갈다', '말다']

# %%
generate_wordcloud_sw(ddae_outlier, 'yeogi', ddae_stop)
